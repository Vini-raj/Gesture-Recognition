# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import os
import imageio
from skimage.transform import resize, rescale
import datetime
import os

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import tensorflow as tf
print(tf.__version__)
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
tf.random.set_seed(30)
# Out:
# 2.12.0

# %%
train_doc = np.random.permutation(open('/kaggle/input/gesture-recognition/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/kaggle/input/gesture-recognition/Project_data/val.csv').readlines())
num_classes = 5  #number of softmax classes

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/kaggle/input/gesture-recognition/Project_data/train'
val_path = '/kaggle/input/gesture-recognition/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
# Out:
# # training sequences = 663
# # validation sequences = 100

# %%
def plot_loss_accuracy(history):
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
def calculate_steps(num_train_sequences, num_val_sequences, batch_size):
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    return steps_per_epoch,validation_steps

# %%
def model_callbacks(folder_name):
    model_name = str(folder_name) + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
   
    if not os.path.exists(model_name):
        os.mkdir(model_name)

    filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

    LR = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=0.0001, cooldown=1, verbose=1) # write the REducelronplateau code here

    return [checkpoint, LR]

# %%
from keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing.image import smart_resize

datagen = ImageDataGenerator(
    zoom_range=0.1,
    zca_whitening=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

## Test code start
#360 by 360
image1 = imageio.imread("/kaggle/input/gesture-recognition/Project_data/train/WIN_20180907_15_38_17_Pro_Left Swipe_new_Left Swipe_new/WIN_20180907_15_38_17_Pro_00037.png")
#160 by 120
image2 = imageio.imread("/kaggle/input/gesture-recognition/Project_data/train/WIN_20180907_15_55_27_Pro_Thumbs Down_new/WIN_20180907_15_55_27_Pro_00014.png")
#crop the images and resize them. Note that the images are of 2 different shape 
#and the conv3D will throw error if the inputs in a batch have different shapes                    
#print(image1.shape, image2.shape)
image1 = resize(image1, (120, 120), anti_aliasing=True)
image1 = datagen.random_transform(image1)                   
plt.imshow(image1)
plt.show()
image2 = resize(image2, (120, 120), anti_aliasing=True)
image2 = datagen.random_transform(image2)                 
plt.imshow(image2)
plt.show()
## Test code end

def generate(source_path, folder_list, batch_size, num_images=20, height=120, width=120, augment=False):
    #print( 'Source path = ', source_path, '; batch size =', batch_size)
    total_frames = 30

    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        #img_idx = sorted(rn.sample(range(0, total_frames), num_images)) #create a list of image numbers you want to use for a particular video
        img_idx = np.round(np.linspace(0,total_frames-1,num_images)).astype(int) #create a list of image numbers you want to use for a particular video

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data   = np.zeros((batch_size, num_images, height, width, 3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, 5)) # batch_labels is the one hot representation of the output           

            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes                    
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image                  
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
        
        # write the code for the remaining data points which are left after full batches
        if (len(t)%batch_size):
            remaining_batch_size = len(t)%batch_size
            batch_data   = np.zeros((remaining_batch_size, num_images, height, width,3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_batch_size,5)) # batch_labels is the one hot representation of the output           

            for folder in range(remaining_batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)                          
                    
                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image
                    #batch_data[folder,idx,:,:,0] = (image[...,0] - image[...,0].min())/(image[...,0].max() - image[...,0].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,1] = (image[...,1] - image[...,1].min())/(image[...,1].max() - image[...,1].min())#normalise and feed in the image
                    #batch_data[folder,idx,:,:,2] = (image[...,2] - image[...,2].min())/(image[...,2].max() - image[...,2].min())#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from keras import optimizers

# %%
# Common utility to create conv 3D models
def conv3D(conv_filters=(16, 32, 64, 128), dense_nodes=(256,128), dropout=0.25, num_images=20, height=120, width=120):

    model = Sequential()

    model.add(Conv3D(conv_filters[0], (3, 3, 3), padding='same', input_shape=(num_images, height, width, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(conv_filters[1], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[2], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[3], (3, 3, 3), padding='same'))    
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    model.add(Dense(dense_nodes[0]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(dense_nodes[1]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    opt = optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    
    return model

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10 #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 120, 120, 16)  1312
#
#  activation (Activation)     (None, 30, 120, 120, 16)  0
#
#  batch_normalization (BatchN  (None, 30, 120, 120, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 15, 60, 60, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 15, 60, 60, 32)    13856
#
#  activation_1 (Activation)   (None, 15, 60, 60, 32)    0
#
#  batch_normalization_1 (Batc  (None, 15, 60, 60, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 7, 30, 30, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 7, 30, 30, 64)     55360
#
#  activation_2 (Activation)   (None, 7, 30, 30, 64)     0
#
#  batch_normalization_2 (Batc  (None, 7, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 3, 15, 15, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 3, 15, 15, 128)    221312
#
#  activation_3 (Activation)   (None, 3, 15, 15, 128)    0
#
#  batch_normalization_3 (Batc  (None, 3, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 256)               1605888
#
#  activation_4 (Activation)   (None, 256)               0
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  activation_5 (Activation)   (None, 128)               0
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
#  activation_6 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_1")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                             callbacks=callbacks_list, validation_data=val_generator, 
                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
# 67/67 [==============================] - ETA: 0s - loss: 1.5663 - categorical_accuracy: 0.4495
# Epoch 1: val_loss improved from inf to 2.01140, saving model to model_conv3D_1_2023-08-2501_47_23.243481/model-00001-1.56626-0.44947-2.01140-0.28000.h5
# 67/67 [==============================] - 280s 4s/step - loss: 1.5663 - categorical_accuracy: 0.4495 - val_loss: 2.0114 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 2/15
# 67/67 [==============================] - ETA: 0s - loss: 1.2659 - categorical_accuracy: 0.5264
# Epoch 2: val_loss improved from 2.01140 to 1.91448, saving model to model_conv3D_1_2023-08-2501_47_23.243481/model-00002-1.26594-0.52640-1.91448-0.35000.h5
# 67/67 [==============================] - 216s 3s/step - loss: 1.2659 - categorical_accuracy: 0.5264 - val_loss: 1.9145 - val_categorical_accuracy: 0.3500 - lr: 0.0010
# Epoch 3/15
# 67/67 [==============================] - ETA: 0s - loss: 1.0697 - categorical_accuracy: 0.5747
# Epoch 3: val_loss did not improve from 1.91448
# 67/67 [==============================] - 218s 3s/step - loss: 1.0697 - categorical_accuracy: 0.5747 - val_loss: 2.7417 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 4/15
# 67/67 [==============================] - ETA: 0s - loss: 0.9346 - categorical_accuracy: 0.6365
# Epoch 4: val_loss improved from 1.91448 to 1.54301, saving model to model_conv3D_1_2023-08-2501_47_23.243481/model-00004-0.93460-0.63650-1.54301-0.46000.h5
# 67/67 [==============================] - 219s 3s/step - loss: 0.9346 - categorical_accuracy: 0.6365 - val_loss: 1.5430 - val_categorical_accuracy: 0.4600 - lr: 0.0010
# Epoch 5/15
# 67/67 [==============================] - ETA: 0s - loss: 0.9475 - categorical_accuracy: 0.6531
# Epoch 5: val_loss improved from 1.54301 to 1.52877, saving model to model_conv3D_1_2023-08-2501_47_23.243481/model-00005-0.94752-0.65309-1.52877-0.43000.h5
# 67/67 [==============================] - 210s 3s/step - loss: 0.9475 - categorical_accuracy: 0.6531 - val_loss: 1.5288 - val_categorical_accuracy: 0.4300 - lr: 0.0010
# Epoch 6/15
# 67/67 [==============================] - ETA: 0s - loss: 0.8377 - categorical_accuracy: 0.6802
# Epoch 6: val_loss improved from 1.52877 to 1.28078, saving model to model_conv3D_1_2023-08-2501_47_23.243481/model-00006-0.83771-0.68024-1.28078-0.53000.h5
# 67/67 [==============================] - 209s 3s/step - loss: 0.8377 - categorical_accuracy: 0.6802 - val_loss: 1.2808 - val_categorical_accuracy: 0.5300 - lr: 0.0010
# Epoch 7/15
# 67/67 [==============================] - ETA: 0s - loss: 0.7687 - categorical_accuracy: 0.7119
# Epoch 7: val_loss did not improve from 1.28078
# 67/67 [==============================] - 217s 3s/step - loss: 0.7687 - categorical_accuracy: 0.7119 - val_loss: 1.3591 - val_categorical_accuracy: 0.4800 - lr: 0.0010
# Epoch 8/15
# 67/67 [==============================] - ETA: 0s - loss: 0.6094 - categorical_accuracy: 0.7526
# Epoch 8: val_loss did not improve from 1.28078
# 67/67 [==============================] - 218s 3s/step - loss: 0.6094 - categorical_accuracy: 0.7526 - val_loss: 1.4601 - val_categorical_accuracy: 0.4800 - lr: 0.0010
# Epoch 9/15
# 67/67 [==============================] - ETA: 0s - loss: 0.6600 - categorical_accuracy: 0.7496
# Epoch 9: val_loss improved from 1.28078 to 0.88953, saving model to model_conv3D_1_2023-08-2501_47_23.243481/model-00009-0.66002-0.74962-0.88953-0.67000.h5
# 67/67 [==============================] - 208s 3s/step - loss: 0.6600 - categorical_accuracy: 0.7496 - val_loss: 0.8895 - val_categorical_accuracy: 0.6700 - lr: 0.0010
# Epoch 10/15
# 67/67 [==============================] - ETA: 0s - loss: 0.7103 - categorical_accuracy: 0.7210
# Epoch 10: val_loss did not improve from 0.88953
# 67/67 [==============================] - 217s 3s/step - loss: 0.7103 - categorical_accuracy: 0.7210 - val_loss: 4.3981 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 11/15
# 67/67 [==============================] - ETA: 0s - loss: 0.5459 - categorical_accuracy: 0.8039
# Epoch 11: val_loss did not improve from 0.88953
# 67/67 [==============================] - 217s 3s/step - loss: 0.5459 - categorical_accuracy: 0.8039 - val_loss: 2.1826 - val_categorical_accuracy: 0.4400 - lr: 0.0010
# Epoch 12/15
# 67/67 [==============================] - ETA: 0s - loss: 0.4604 - categorical_accuracy: 0.8235
# Epoch 12: val_loss did not improve from 0.88953
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 209s 3s/step - loss: 0.4604 - categorical_accuracy: 0.8235 - val_loss: 1.4894 - val_categorical_accuracy: 0.5200 - lr: 0.0010
# Epoch 13/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3666 - categorical_accuracy: 0.8612
# Epoch 13: val_loss improved from 0.88953 to 0.78797, saving model to model_conv3D_1_2023-08-2501_47_23.243481/model-00013-0.36659-0.86124-0.78797-0.70000.h5
# 67/67 [==============================] - 216s 3s/step - loss: 0.3666 - categorical_accuracy: 0.8612 - val_loss: 0.7880 - val_categorical_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 14/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3346 - categorical_accuracy: 0.8522
# Epoch 14: val_loss improved from 0.78797 to 0.61694, saving model to model_conv3D_1_2023-08-2501_47_23.243481/model-00014-0.33463-0.85219-0.61694-0.79000.h5
# 67/67 [==============================] - 209s 3s/step - loss: 0.3346 - categorical_accuracy: 0.8522 - val_loss: 0.6169 - val_categorical_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 15/15
# 67/67 [==============================] - ETA: 0s - loss: 0.2990 - categorical_accuracy: 0.8944
# Epoch 15: val_loss did not improve from 0.61694
# 67/67 [==============================] - 217s 3s/step - loss: 0.2990 - categorical_accuracy: 0.8944 - val_loss: 0.6713 - val_categorical_accuracy: 0.7800 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# Conv 3D Model with 20 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 20 # choose the number of epochs
#print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 20, 120, 120, 16)  1312
#
#  activation_7 (Activation)   (None, 20, 120, 120, 16)  0
#
#  batch_normalization_6 (Batc  (None, 20, 120, 120, 16)  64
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 10, 60, 60, 16)   0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 10, 60, 60, 32)    13856
#
#  activation_8 (Activation)   (None, 10, 60, 60, 32)    0
#
#  batch_normalization_7 (Batc  (None, 10, 60, 60, 32)   128
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 5, 30, 30, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 5, 30, 30, 64)     55360
#
#  activation_9 (Activation)   (None, 5, 30, 30, 64)     0
#
#  batch_normalization_8 (Batc  (None, 5, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 2, 15, 15, 64)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 2, 15, 15, 128)    221312
#
#  activation_10 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_9 (Batc  (None, 2, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_3 (Dense)             (None, 256)               1605888
#
#  activation_11 (Activation)  (None, 256)               0
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  activation_12 (Activation)  (None, 128)               0
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
#  activation_13 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_2")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 67/67 [==============================] - ETA: 0s - loss: 1.5222 - categorical_accuracy: 0.4495
# Epoch 1: val_loss improved from inf to 2.52848, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00001-1.52218-0.44947-2.52848-0.29000.h5
# 67/67 [==============================] - 142s 2s/step - loss: 1.5222 - categorical_accuracy: 0.4495 - val_loss: 2.5285 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 1.0043 - categorical_accuracy: 0.6078
# Epoch 2: val_loss did not improve from 2.52848
# 67/67 [==============================] - 157s 2s/step - loss: 1.0043 - categorical_accuracy: 0.6078 - val_loss: 2.5708 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss: 0.8226 - categorical_accuracy: 0.6757
# Epoch 3: val_loss did not improve from 2.52848
# 67/67 [==============================] - 158s 2s/step - loss: 0.8226 - categorical_accuracy: 0.6757 - val_loss: 3.1644 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 4/20
# 67/67 [==============================] - ETA: 0s - loss: 0.8177 - categorical_accuracy: 0.6968
# Epoch 4: val_loss did not improve from 2.52848
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 138s 2s/step - loss: 0.8177 - categorical_accuracy: 0.6968 - val_loss: 3.0391 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 5/20
# 67/67 [==============================] - ETA: 0s - loss: 0.5712 - categorical_accuracy: 0.7858
# Epoch 5: val_loss did not improve from 2.52848
# 67/67 [==============================] - 139s 2s/step - loss: 0.5712 - categorical_accuracy: 0.7858 - val_loss: 2.6128 - val_categorical_accuracy: 0.2900 - lr: 1.0000e-04
# Epoch 6/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4822 - categorical_accuracy: 0.8175
# Epoch 6: val_loss improved from 2.52848 to 2.09666, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00006-0.48219-0.81750-2.09666-0.28000.h5
# 67/67 [==============================] - 139s 2s/step - loss: 0.4822 - categorical_accuracy: 0.8175 - val_loss: 2.0967 - val_categorical_accuracy: 0.2800 - lr: 1.0000e-04
# Epoch 7/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4188 - categorical_accuracy: 0.8597
# Epoch 7: val_loss improved from 2.09666 to 1.80157, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00007-0.41878-0.85973-1.80157-0.33000.h5
# 67/67 [==============================] - 138s 2s/step - loss: 0.4188 - categorical_accuracy: 0.8597 - val_loss: 1.8016 - val_categorical_accuracy: 0.3300 - lr: 1.0000e-04
# Epoch 8/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4145 - categorical_accuracy: 0.8522
# Epoch 8: val_loss improved from 1.80157 to 1.43023, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00008-0.41449-0.85219-1.43023-0.41000.h5
# 67/67 [==============================] - 139s 2s/step - loss: 0.4145 - categorical_accuracy: 0.8522 - val_loss: 1.4302 - val_categorical_accuracy: 0.4100 - lr: 1.0000e-04
# Epoch 9/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3681 - categorical_accuracy: 0.8688
# Epoch 9: val_loss improved from 1.43023 to 1.09190, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00009-0.36814-0.86878-1.09190-0.56000.h5
# 67/67 [==============================] - 137s 2s/step - loss: 0.3681 - categorical_accuracy: 0.8688 - val_loss: 1.0919 - val_categorical_accuracy: 0.5600 - lr: 1.0000e-04
# Epoch 10/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3040 - categorical_accuracy: 0.9155
# Epoch 10: val_loss improved from 1.09190 to 0.65164, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00010-0.30399-0.91554-0.65164-0.72000.h5
# 67/67 [==============================] - 157s 2s/step - loss: 0.3040 - categorical_accuracy: 0.9155 - val_loss: 0.6516 - val_categorical_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 11/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3353 - categorical_accuracy: 0.8763
# Epoch 11: val_loss improved from 0.65164 to 0.58377, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00011-0.33532-0.87632-0.58377-0.76000.h5
# 67/67 [==============================] - 158s 2s/step - loss: 0.3353 - categorical_accuracy: 0.8763 - val_loss: 0.5838 - val_categorical_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 12/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3142 - categorical_accuracy: 0.8839
# Epoch 12: val_loss improved from 0.58377 to 0.57777, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00012-0.31421-0.88386-0.57777-0.78000.h5
# 67/67 [==============================] - 140s 2s/step - loss: 0.3142 - categorical_accuracy: 0.8839 - val_loss: 0.5778 - val_categorical_accuracy: 0.7800 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2922 - categorical_accuracy: 0.9080
# Epoch 13: val_loss did not improve from 0.57777
# 67/67 [==============================] - 138s 2s/step - loss: 0.2922 - categorical_accuracy: 0.9080 - val_loss: 0.7502 - val_categorical_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2482 - categorical_accuracy: 0.9201
# Epoch 14: val_loss improved from 0.57777 to 0.48608, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00014-0.24824-0.92006-0.48608-0.78000.h5
# 67/67 [==============================] - 158s 2s/step - loss: 0.2482 - categorical_accuracy: 0.9201 - val_loss: 0.4861 - val_categorical_accuracy: 0.7800 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2346 - categorical_accuracy: 0.9261
# Epoch 15: val_loss improved from 0.48608 to 0.36928, saving model to model_conv3D_2_2023-08-2501_47_23.243481/model-00015-0.23462-0.92609-0.36928-0.88000.h5
# 67/67 [==============================] - 140s 2s/step - loss: 0.2346 - categorical_accuracy: 0.9261 - val_loss: 0.3693 - val_categorical_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2189 - categorical_accuracy: 0.9231
# Epoch 16: val_loss did not improve from 0.36928
# 67/67 [==============================] - 145s 2s/step - loss: 0.2189 - categorical_accuracy: 0.9231 - val_loss: 0.6049 - val_categorical_accuracy: 0.8100 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2478 - categorical_accuracy: 0.9155
# Epoch 17: val_loss did not improve from 0.36928
# 67/67 [==============================] - 139s 2s/step - loss: 0.2478 - categorical_accuracy: 0.9155 - val_loss: 0.4256 - val_categorical_accuracy: 0.8300 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1570 - categorical_accuracy: 0.9578
# Epoch 18: val_loss did not improve from 0.36928
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 157s 2s/step - loss: 0.1570 - categorical_accuracy: 0.9578 - val_loss: 0.6612 - val_categorical_accuracy: 0.7300 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1589 - categorical_accuracy: 0.9532
# Epoch 19: val_loss did not improve from 0.36928
# 67/67 [==============================] - 158s 2s/step - loss: 0.1589 - categorical_accuracy: 0.9532 - val_loss: 0.5943 - val_categorical_accuracy: 0.7900 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1762 - categorical_accuracy: 0.9382
# Epoch 20: val_loss did not improve from 0.36928
# 67/67 [==============================] - 157s 2s/step - loss: 0.1762 - categorical_accuracy: 0.9382 - val_loss: 0.7141 - val_categorical_accuracy: 0.7500 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# Conv 3D Model with 30 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 160 by 160)

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 160
width = 160

model = conv3D(num_images=num_frames, height=160, width=160)

print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 30, 160, 160, 16)  1312
#
#  activation_14 (Activation)  (None, 30, 160, 160, 16)  0
#
#  batch_normalization_12 (Bat  (None, 30, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 15, 80, 80, 16)   0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 15, 80, 80, 32)    13856
#
#  activation_15 (Activation)  (None, 15, 80, 80, 32)    0
#
#  batch_normalization_13 (Bat  (None, 15, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 7, 40, 40, 32)    0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 7, 40, 40, 64)     55360
#
#  activation_16 (Activation)  (None, 7, 40, 40, 64)     0
#
#  batch_normalization_14 (Bat  (None, 7, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 3, 20, 20, 64)    0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 3, 20, 20, 128)    221312
#
#  activation_17 (Activation)  (None, 3, 20, 20, 128)    0
#
#  batch_normalization_15 (Bat  (None, 3, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_2 (Flatten)         (None, 12800)             0
#
#  dense_6 (Dense)             (None, 256)               3277056
#
#  activation_18 (Activation)  (None, 256)               0
#
#  batch_normalization_16 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  activation_19 (Activation)  (None, 128)               0
#
#  batch_normalization_17 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 5)                 645
#
#  activation_20 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 3,604,933
# Trainable params: 3,603,685
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The steps_per_epoch and validation_steps are used by fit_generator to decide the number of next() calls it need to make. Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_3")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames, height=160, width=160)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames, height=160, width=160)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 67/67 [==============================] - ETA: 0s - loss: 1.5189 - categorical_accuracy: 0.4525
# Epoch 1: val_loss improved from inf to 5.80243, saving model to model_conv3D_3_2023-08-2501_47_23.243481/model-
- val_categorical_accuracy: 0.7800 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# Conv 3D Model with 20 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 160 by 160)

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 160
width = 160

model = conv3D(num_images=num_frames, height=160, width=160)

print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_21 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_18 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_12 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_13 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_22 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_19 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_13 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_23 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_20 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_14 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_15 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_24 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_21 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_15 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_9 (Dense)             (None, 256)               3277056
#
#  activation_25 (Activation)  (None, 256)               0
#
#  batch_normalization_22 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  activation_26 (Activation)  (None, 128)               0
#
#  batch_normalization_23 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 5)                 645
#
#  activation_27 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 3,604,933
# Trainable params: 3,603,685
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %% [markdown]
# The steps_per_epoch and validation_steps are used by fit_generator to decide the number of next() calls it need to make. Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_4")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames, height=160, width=160)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames, height=160, width=160)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 67/67 [==============================] - ETA: 0s - loss: 1.4775 - categorical_accuracy: 0.4510
# Epoch 1: val_loss improved from inf to 3.97163, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00001-1.47755-0.45098-3.97163-0.17000.h5
# 67/67 [==============================] - 180s 3s/step - loss: 1.4775 - categorical_accuracy: 0.4510 - val_loss: 3.9716 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 1.0834 - categorical_accuracy: 0.6033
# Epoch 2: val_loss did not improve from 3.97163
# 67/67 [==============================] - 193s 3s/step - loss: 1.0834 - categorical_accuracy: 0.6033 - val_loss: 4.7945 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss: 0.8832 - categorical_accuracy: 0.6606
# Epoch 3: val_loss did not improve from 3.97163
# 67/67 [==============================] - 183s 3s/step - loss: 0.8832 - categorical_accuracy: 0.6606 - val_loss: 8.0074 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 4/20
# 67/67 [==============================] - ETA: 0s - loss: 0.8865 - categorical_accuracy: 0.6742
# Epoch 4: val_loss did not improve from 3.97163
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 181s 3s/step - loss: 0.8865 - categorical_accuracy: 0.6742 - val_loss: 7.2903 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 5/20
# 67/67 [==============================] - ETA: 0s - loss: 0.7449 - categorical_accuracy: 0.7240
# Epoch 5: val_loss did not improve from 3.97163
# 67/67 [==============================] - 180s 3s/step - loss: 0.7449 - categorical_accuracy: 0.7240 - val_loss: 3.9869 - val_categorical_accuracy: 0.2400 - lr: 1.0000e-04
# Epoch 6/20
# 67/67 [==============================] - ETA: 0s - loss: 0.5868 - categorical_accuracy: 0.7813
# Epoch 6: val_loss improved from 3.97163 to 2.46783, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00006-0.58680-0.78130-2.46783-0.35000.h5
# 67/67 [==============================] - 192s 3s/step - loss: 0.5868 - categorical_accuracy: 0.7813 - val_loss: 2.4678 - val_categorical_accuracy: 0.3500 - lr: 1.0000e-04
# Epoch 7/20
# 67/67 [==============================] - ETA: 0s - loss: 0.5899 - categorical_accuracy: 0.7677
# Epoch 7: val_loss improved from 2.46783 to 1.74282, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00007-0.58988-0.76772-1.74282-0.38000.h5
# 67/67 [==============================] - 193s 3s/step - loss: 0.5899 - categorical_accuracy: 0.7677 - val_loss: 1.7428 - val_categorical_accuracy: 0.3800 - lr: 1.0000e-04
# Epoch 8/20
# 67/67 [==============================] - ETA: 0s - loss: 0.5569 - categorical_accuracy: 0.7949
# Epoch 8: val_loss improved from 1.74282 to 1.39839, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00008-0.55687-0.79487-1.39839-0.55000.h5
# 67/67 [==============================] - 194s 3s/step - loss: 0.5569 - categorical_accuracy: 0.7949 - val_loss: 1.3984 - val_categorical_accuracy: 0.5500 - lr: 1.0000e-04
# Epoch 9/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4949 - categorical_accuracy: 0.8100
# Epoch 9: val_loss improved from 1.39839 to 1.03111, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00009-0.49486-0.80995-1.03111-0.61000.h5
# 67/67 [==============================] - 181s 3s/step - loss: 0.4949 - categorical_accuracy: 0.8100 - val_loss: 1.0311 - val_categorical_accuracy: 0.6100 - lr: 1.0000e-04
# Epoch 10/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4428 - categorical_accuracy: 0.8281
# Epoch 10: val_loss improved from 1.03111 to 0.70585, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00010-0.44279-0.82805-0.70585-0.73000.h5
# 67/67 [==============================] - 192s 3s/step - loss: 0.4428 - categorical_accuracy: 0.8281 - val_loss: 0.7058 - val_categorical_accuracy: 0.7300 - lr: 1.0000e-04
# Epoch 11/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4484 - categorical_accuracy: 0.8250
# Epoch 11: val_loss did not improve from 0.70585
# 67/67 [==============================] - 180s 3s/step - loss: 0.4484 - categorical_accuracy: 0.8250 - val_loss: 0.7617 - val_categorical_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 12/20
# 67/67 [==============================] - ETA: 0s - loss: 0.4714 - categorical_accuracy: 0.8296
# Epoch 12: val_loss improved from 0.70585 to 0.54787, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00012-0.47141-0.82956-0.54787-0.77000.h5
# 67/67 [==============================] - 180s 3s/step - loss: 0.4714 - categorical_accuracy: 0.8296 - val_loss: 0.5479 - val_categorical_accuracy: 0.7700 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3794 - categorical_accuracy: 0.8703
# Epoch 13: val_loss improved from 0.54787 to 0.50631, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00013-0.37941-0.87029-0.50631-0.84000.h5
# 67/67 [==============================] - 181s 3s/step - loss: 0.3794 - categorical_accuracy: 0.8703 - val_loss: 0.5063 - val_categorical_accuracy: 0.8400 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3856 - categorical_accuracy: 0.8673
# Epoch 14: val_loss improved from 0.50631 to 0.48787, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00014-0.38559-0.86727-0.48787-0.82000.h5
# 67/67 [==============================] - 193s 3s/step - loss: 0.3856 - categorical_accuracy: 0.8673 - val_loss: 0.4879 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3415 - categorical_accuracy: 0.8627
# Epoch 15: val_loss did not improve from 0.48787
# 67/67 [==============================] - 193s 3s/step - loss: 0.3415 - categorical_accuracy: 0.8627 - val_loss: 0.6231 - val_categorical_accuracy: 0.7400 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3139 - categorical_accuracy: 0.8929
# Epoch 16: val_loss improved from 0.48787 to 0.45759, saving model to model_conv3D_4_2023-08-2501_47_23.243481/model-00016-0.31391-0.89291-0.45759-0.87000.h5
# 67/67 [==============================] - 184s 3s/step - loss: 0.3139 - categorical_accuracy: 0.8929 - val_loss: 0.4576 - val_categorical_accuracy: 0.8700 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3645 - categorical_accuracy: 0.8703
# Epoch 17: val_loss did not improve from 0.45759
# 67/67 [==============================] - 194s 3s/step - loss: 0.3645 - categorical_accuracy: 0.8703 - val_loss: 0.4918 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2935 - categorical_accuracy: 0.8989
# Epoch 18: val_loss did not improve from 0.45759
# 67/67 [==============================] - 193s 3s/step - loss: 0.2935 - categorical_accuracy: 0.8989 - val_loss: 0.5383 - val_categorical_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2903 - categorical_accuracy: 0.8854
# Epoch 19: val_loss did not improve from 0.45759
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 193s 3s/step - loss: 0.2903 - categorical_accuracy: 0.8854 - val_loss: 0.4822 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2168 - categorical_accuracy: 0.9246
# Epoch 20: val_loss did not improve from 0.45759
# 67/67 [==============================] - 196s 3s/step - loss: 0.2168 - categorical_accuracy: 0.9246 - val_loss: 0.5778 - val_categorical_accuracy: 0.8000 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# Conv 3D Model with 30 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer) + Random data transformations on training data set

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_16 (Conv3D)          (None, 30, 120, 120, 16)  1312
#
#  activation_28 (Activation)  (None, 30, 120, 120, 16)  0
#
#  batch_normalization_24 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_16 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_17 (Conv3D)          (None, 15, 60, 60, 32)    13856
#
#  activation_29 (Activation)  (None, 15, 60, 60, 32)    0
#
#  batch_normalization_25 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_17 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_18 (Conv3D)          (None, 7, 30, 30, 64)     55360
#
#  activation_30 (Activation)  (None, 7, 30, 30, 64)     0
#
#  batch_normalization_26 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_18 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_19 (Conv3D)          (None, 3, 15, 15, 128)    221312
#
#  activation_31 (Activation)  (None, 3, 15, 15, 128)    0
#
#  batch_normalization_27 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_19 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_4 (Flatten)         (None, 6272)              0
#
#  dense_12 (Dense)            (None, 256)               1605888
#
#  activation_32 (Activation)  (None, 256)               0
#
#  batch_normalization_28 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  activation_33 (Activation)  (None, 128)               0
#
#  batch_normalization_29 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 5)                 645
#
#  activation_34 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 1,933,765
# Trainable params: 1,932,517
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_5")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
# 67/67 [==============================] - ETA: 0s - loss: 0.
accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 12/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3924 - categorical_accuracy: 0.8507
# Epoch 12: val_loss did not improve from 0.78695
# 67/67 [==============================] - 246s 4s/step - loss: 0.3924 - categorical_accuracy: 0.8507 - val_loss: 0.8141 - val_categorical_accuracy: 0.7700 - lr: 1.0000e-04
# Epoch 13/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3903 - categorical_accuracy: 0.8627
# Epoch 13: val_loss did not improve from 0.78695
# 67/67 [==============================] - 247s 4s/step - loss: 0.3903 - categorical_accuracy: 0.8627 - val_loss: 1.1006 - val_categorical_accuracy: 0.6200 - lr: 1.0000e-04
# Epoch 14/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3681 - categorical_accuracy: 0.8808
# Epoch 14: val_loss did not improve from 0.78695
# 67/67 [==============================] - 236s 4s/step - loss: 0.3681 - categorical_accuracy: 0.8808 - val_loss: 0.8034 - val_categorical_accuracy: 0.7300 - lr: 1.0000e-04
# Epoch 15/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3707 - categorical_accuracy: 0.8944
# Epoch 15: val_loss did not improve from 0.78695
# 67/67 [==============================] - 239s 4s/step - loss: 0.3707 - categorical_accuracy: 0.8944 - val_loss: 0.8024 - val_categorical_accuracy: 0.8000 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# Conv 3D Model with 30 frames per video (8, 16, 32, 64 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

conv_filters = (8, 16, 32, 64) 
model = conv3D(conv_filters, num_images=num_frames)
print (model.summary())
# Out:
# # epochs = 25
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_20 (Conv3D)          (None, 30, 120, 120, 8)   656
#
#  activation_35 (Activation)  (None, 30, 120, 120, 8)   0
#
#  batch_normalization_30 (Bat  (None, 30, 120, 120, 8)  32
#  chNormalization)
#
#  max_pooling3d_20 (MaxPoolin  (None, 15, 60, 60, 8)    0
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 15, 60, 60, 16)    3472
#
#  activation_36 (Activation)  (None, 15, 60, 60, 16)    0
#
#  batch_normalization_31 (Bat  (None, 15, 60, 60, 16)   64
#  chNormalization)
#
#  max_pooling3d_21 (MaxPoolin  (None, 7, 30, 30, 16)    0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 7, 30, 30, 32)     13856
#
#  activation_37 (Activation)  (None, 7, 30, 30, 32)     0
#
#  batch_normalization_32 (Bat  (None, 7, 30, 30, 32)    128
#  chNormalization)
#
#  max_pooling3d_22 (MaxPoolin  (None, 3, 15, 15, 32)    0
#  g3D)
#
#  conv3d_23 (Conv3D)          (None, 3, 15, 15, 64)     55360
#
#  activation_38 (Activation)  (None, 3, 15, 15, 64)     0
#
#  batch_normalization_33 (Bat  (None, 3, 15, 15, 64)    256
#  chNormalization)
#
#  max_pooling3d_23 (MaxPoolin  (None, 1, 7, 7, 64)      0
#  g3D)
#
#  flatten_5 (Flatten)         (None, 3136)              0
#
#  dense_15 (Dense)            (None, 256)               803072
#
#  activation_39 (Activation)  (None, 256)               0
#
#  batch_normalization_34 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 128)               32896
#
#  activation_40 (Activation)  (None, 128)               0
#
#  batch_normalization_35 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 5)                 645
#
#  activation_41 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 911,973
# Trainable params: 910,965
# Non-trainable params: 1,008
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_6")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1
- val_categorical_accuracy: 0.7400 - lr: 1.0000e-04
# Epoch 11/15
# 67/67 [==============================] - ETA: 0s - loss: 0.4755 - categorical_accuracy: 0.8265
# Epoch 11: val_loss improved from 0.79918 to 0.68160, saving model to model_conv3D_1_2023-08-2513_52_56.201412/model-00011-0.47548-0.82655-0.68160-0.78000.h5
# 67/67 [==============================] - 225s 3s/step - loss: 0.4755 - categorical_accuracy: 0.8265 - val_loss: 0.6816 - val_categorical_accuracy: 0.7800 - lr: 1.0000e-04
# Epoch 12/15
# 67/67 [==============================] - ETA: 0s - loss: 0.4424 - categorical_accuracy: 0.8356
# Epoch 12: val_loss did not improve from 0.68160
# 67/67 [==============================] - 241s 4s/step - loss: 0.4424 - categorical_accuracy: 0.8356 - val_loss: 0.9856 - val_categorical_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 13/15
# 67/67 [==============================] - ETA: 0s - loss: 0.4213 - categorical_accuracy: 0.8492
# Epoch 13: val_loss improved from 0.68160 to 0.52805, saving model to model_conv3D_1_2023-08-2513_52_56.201412/model-00013-0.42132-0.84917-0.52805-0.83000.h5
# 67/67 [==============================] - 216s 3s/step - loss: 0.4213 - categorical_accuracy: 0.8492 - val_loss: 0.5281 - val_categorical_accuracy: 0.8300 - lr: 1.0000e-04
# Epoch 14/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3589 - categorical_accuracy: 0.8658
# Epoch 14: val_loss did not improve from 0.52805
# 67/67 [==============================] - 211s 3s/step - loss: 0.3589 - categorical_accuracy: 0.8658 - val_loss: 0.7935 - val_categorical_accuracy: 0.7200 - lr: 1.0000e-04
# Epoch 15/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3867 - categorical_accuracy: 0.8582
# Epoch 15: val_loss did not improve from 0.52805
# 67/67 [==============================] - 225s 3s/step - loss: 0.3867 - categorical_accuracy: 0.8582 - val_loss: 0.7788 - val_categorical_accuracy: 0.7800 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# Conv 3D Model with 20 frames per video (16, 32, 64, 128 filters conv 3D layers + 128 dense layer + 64 dense layer + image size 120 by 120)

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

conv_filters = (16, 32, 64, 128)
dense_filters = (128, 64) 
model = conv3D(conv_filters=conv_filters, dense_nodes=dense_filters, dropout=0.2, num_images=num_frames)
print (model.summary())
# Out:
# # epochs = 25
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_4 (Conv3D)           (None, 30, 120, 120, 16)  1312
#
#  activation_7 (Activation)   (None, 30, 120, 120, 16)  0
#
#  batch_normalization_6 (Batc  (None, 30, 120, 120, 16)  64
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 15, 60, 60, 16)   0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 15, 60, 60, 32)    13856
#
#  activation_8 (Activation)   (None, 15, 60, 60, 32)    0
#
#  batch_normalization_7 (Batc  (None, 15, 60, 60, 32)   128
#  hNormalization)
#
#  max_pooling3d_5 (MaxPooling  (None, 7, 30, 30, 32)    0
#  3D)
#
#  conv3d_6 (Conv3D)           (None, 7, 30, 30, 64)     55360
#
#  activation_9 (Activation)   (None, 7, 30, 30, 64)     0
#
#  batch_normalization_8 (Batc  (None, 7, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 3, 15, 15, 64)    0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 3, 15, 15, 128)    221312
#
#  activation_10 (Activation)  (None, 3, 15, 15, 128)    0
#
#  batch_normalization_9 (Batc  (None, 3, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_3 (Dense)             (None, 128)               802944
#
#  activation_11 (Activation)  (None, 128)               0
#
#  batch_normalization_10 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#
saving model to model_conv3D_7_2023-08-2513_52_56.201412/model-00020-0.29032-0.89593-0.46199-0.86000.h5
# 67/67 [==============================] - 226s 3s/step - loss: 0.2903 - categorical_accuracy: 0.8959 - val_loss: 0.4620 - val_categorical_accuracy: 0.8600 - lr: 1.0000e-04
# Epoch 21/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2924 - categorical_accuracy: 0.8974
# Epoch 21: val_loss improved from 0.46199 to 0.45824, saving model to model_conv3D_7_2023-08-2513_52_56.201412/model-00021-0.29237-0.89744-0.45824-0.83000.h5
# 67/67 [==============================] - 221s 3s/step - loss: 0.2924 - categorical_accuracy: 0.8974 - val_loss: 0.4582 - val_categorical_accuracy: 0.8300 - lr: 1.0000e-04
# Epoch 22/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2557 - categorical_accuracy: 0.9155
# Epoch 22: val_loss did not improve from 0.45824
# 67/67 [==============================] - 212s 3s/step - loss: 0.2557 - categorical_accuracy: 0.9155 - val_loss: 0.4979 - val_categorical_accuracy: 0.8600 - lr: 1.0000e-04
# Epoch 23/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2232 - categorical_accuracy: 0.9321
# Epoch 23: val_loss improved from 0.45824 to 0.40960, saving model to model_conv3D_7_2023-08-2513_52_56.201412/model-00023-0.22318-0.93213-0.40960-0.82000.h5
# 67/67 [==============================] - 215s 3s/step - loss: 0.2232 - categorical_accuracy: 0.9321 - val_loss: 0.4096 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04
# Epoch 24/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2228 - categorical_accuracy: 0.9261
# Epoch 24: val_loss improved from 0.40960 to 0.39852, saving model to model_conv3D_7_2023-08-2513_52_56.201412/model-00024-0.22284-0.92609-0.39852-0.86000.h5
# 67/67 [==============================] - 212s 3s/step - loss: 0.2228 - categorical_accuracy: 0.9261 - val_loss: 0.3985 - val_categorical_accuracy: 0.8600 - lr: 1.0000e-04
# Epoch 25/25
# 67/67 [==============================] - ETA: 0s - loss: 0.2520 - categorical_accuracy: 0.9216
# Epoch 25: val_loss did not improve from 0.39852
# 67/67 [==============================] - 222s 3s/step - loss: 0.2520 - categorical_accuracy: 0.9216 - val_loss: 0.4662 - val_categorical_accuracy: 0.8200 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# Conv 3D Model with 20 frames per video (32, 64, 128, 256) filters conv 3D layers + 128 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 120
width = 120

conv_filters = (32, 64, 128, 256)
dense_filters = (128, 128)
model = conv3D(conv_filters=conv_filters,dense_nodes=dense_filters, num_images=num_frames)
print (model.summary())
# Out:
# # epochs = 25
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_8 (Conv3D)           (None, 20, 120, 120, 32)  2624
#
#  activation_14 (Activation)  (None, 20, 120, 120, 32)  0
#
#  batch_normalization_12 (Bat  (None, 20, 120, 120, 32)  128
#  chNormalization)
#
#  max_pooling3d_8 (MaxPooling  (None, 10, 60, 60, 32)   0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 10, 60, 60, 64)    55360
#
#  activation_15 (Activation)  (None, 10, 60, 60, 64)    0
#
#  batch_normalization_13 (Bat  (None, 10, 60, 60, 64)   256
#  chNormalization)
#
#  max_pooling3d_9 (MaxPooling  (None, 5, 30, 30, 64)    0
#  3D)
#
#  conv3d_10 (Conv3D)          (None, 5, 30, 30, 128)    221312
#
#  activation_16 (Activation)  (None, 5, 30, 30, 128)    0
#
#  batch_normalization_14 (Bat  (None, 5, 30, 30, 128)   512
#  chNormalization)
#
#  max_pooling3d_10 (MaxPoolin  (None, 2, 15, 15, 128)   0
#  g3D)
#
#  conv3d_11 (Conv3D)          (None, 2, 15, 15, 256)    884992
#
#  activation_17 (Activation)  (None, 2, 15, 15, 256)    0
#
#  batch_normalization_15 (Bat  (None, 2, 15, 15, 256)   1024
#  chNormalization)
#
#  max_pooling3d_11 (MaxPoolin  (None, 1, 7, 7, 256)     0
#  g3D)
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dense_6 (Dense)             (None, 128)               1605760
#
#  activation_18 (Activation)  (None, 128)               0
#
#  batch_normalization_16 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  activation_19 (Activation)  (None, 128)               0
#
#  batch_normalization_17 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 5)                 645
#
#  activation_20 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 2,790,149
# Trainable params: 2,788,677
# Non-trainable params: 1,472
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_8")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=False, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/25
# 67/67 [==============================] - ETA: 0s - loss: 1.7250 - categorical_accuracy: 0.3695
# Epoch 1: val_loss improved from inf to 3.28505, saving model to model_conv3D_8_2023-08-2513_52_56.201412/model-00001-1.72498-0.36953-3.28505-0.22000.h5
# 67/67 [==============================] - 143s 2s/step - loss: 1.7250 - categorical_accuracy: 0.3695 - val_loss: 3.2851 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 2/25
# 67/67 [==============================] - ETA: 0s - loss: 1.2751 - categorical_accuracy: 0.4842
# Epoch 2: val_loss did not improve from 3.28505
# 67/67 [==============================] - 163s 2s/step - loss: 1.2751 - categorical_accuracy: 0.4842 - val_loss: 4.5692 - val_categorical_accuracy: 0.1400 - lr: 0.0010
# Epoch 3/25
# 67/67 [==============================] - ETA: 0s - loss: 1.0934 - categorical_accuracy: 0.5581
# Epoch 3: val_loss did not improve from 3.28505
# 67/67 [==============================] - 148s 2s/step - loss: 1.0934 - categorical_accuracy: 0.5581 - val_loss: 9.5771 - val_categorical_accuracy: 0.1800 - lr: 0.0010
# Epoch 4/25
# 67/67 [==============================] - ETA: 0s - loss: 1.1191 - categorical_accuracy: 0.5611
# Epoch 4: val_loss did not improve from 3.28505
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 151s 2s/step - loss: 1.1191 - categorical_accuracy: 0.5611 - val_loss: 5.0139 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 5/25
# 67/67 [==============================] - ETA: 0s - loss: 0.9436 - categorical_accuracy: 0.6757
# Epoch 5: val_loss did not improve from 3.28505
# 67/67 [==============================] - 152s 2s/step - loss: 0.9436 - categorical_accuracy: 0.6757 - val_loss: 4.3881 - val_categorical_accuracy: 0.3400 - lr: 1.0000e-04
# Epoch 6/25
# 67/67 [==============================] - ETA: 0s - loss: 0.8639 - categorical_accuracy: 0.6606
# Epoch 6: val_loss did not improve from 3.28505
# 67/67 [==============================] - 179s 3s/step - loss: 0.8639 - categorical_accuracy: 0.6606 - val_loss: 4.0060 - val_categorical_accuracy: 0.2800 - lr: 1.0000e-04
# Epoch 7/25
# 67/67 [==============================] - ETA: 0s - loss: 0.8317 - categorical_accuracy: 0.6682
# Epoch 7: val_loss did not improve from 3.28505
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] -
- lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# Conv 3D Model with 30 frames per video and a 5 by 5 filter size (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
#write your model here
def conv3D_5by5(conv_filters=(16, 32, 64, 128), dense_nodes=(256,128), dropout=0.25, num_images=20, height=120, width=120):

    model = Sequential()

    model.add(Conv3D(conv_filters[0], (5, 5, 5), padding='same', input_shape=(num_images, height, width, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(conv_filters[1], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[2], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[3], (3, 3, 3), padding='same'))    
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    model.add(Dense(dense_nodes[0]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(dense_nodes[1]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    opt = optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    
    return model

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D_5by5(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 30, 120, 120, 16)  6016
#
#  activation_21 (Activation)  (None, 30, 120, 120, 16)  0
#
#  batch_normalization_18 (Bat  (None, 30, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_12 (MaxPoolin  (None, 15, 60, 60, 16)   0
#  g3D)
#
#  conv3d_13 (Conv3D)          (None, 15, 60, 60, 32)    13856
#
#  activation_22 (Activation)  (None, 15, 60, 60, 32)    0
#
#  batch_normalization_19 (Bat  (None, 15, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_13 (MaxPoolin  (None, 7, 30, 30, 32)    0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 7, 30, 30, 64)     55360
#
#  activation_23 (Activation)  (None, 7, 30, 30, 64)     0
#
#  batch_normalization_20 (Bat  (None, 7, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_14 (MaxPoolin  (None, 3, 15, 15, 64)    0
#  g3D)
#
#  conv3d_15 (Conv3D)          (None, 3, 15, 15, 128)    221312
#
#  activation_24 (Activation)  (None, 3, 15, 15, 128)    0
#
#  batch_normalization_21 (Bat  (None, 3, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_15 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_3 (Flatten)         (None, 6272)              0
#
#  dense_9 (Dense)             (None, 256)               1605888
#
#  activation_25 (Activation)  (None, 256)               0
#
#  batch_normalization_22 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  activation_26 (Activation)  (None, 128)               0
#
#  batch_normalization_23 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 5)                 645
#
#  activation_27 (Activation)  (None, 5)                 0
#
# =================================================================
# Total params: 1,938,469
# Trainable params: 1,937,221
# Non-trainable params: 1,248
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_conv3D_9")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/15
# 67/67 [==============================] - ETA: 0s - loss: 1.6181 - categorical_accuracy: 0.4223
# Epoch 1: val_loss improved from inf to 2.27238, saving model to model_conv3D_9_2023-08-2513_52_56.201412/model-00001-1.61811-0.42232-2.27238-0.25000.h5
# 67/67 [==============================] - 239s 4s/step - loss: 1.6181 - categorical_accuracy: 0.4223 - val_loss: 2.2724 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 2/15
# 67/67 [==============================] - ETA: 0s - loss: 1.3582 - categorical_accuracy: 0.4872
# Epoch 2: val_loss did not improve from 2.27238
# 67/67 [==============================] - 213s 3s/step - loss: 1.3582 - categorical_accuracy: 0.4872 - val_loss: 3.9264 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 3/15
# 67/67 [==============================] - ETA: 0s - loss: 1.0902 - categorical_accuracy: 0.5581
# Epoch 3: val_loss did not improve from 2.27238
# 67/67 [==============================] - 214s 3s/step - loss: 1.0902 - categorical_accuracy: 0.5581 - val_loss: 4.3647 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 225s 3s/step - loss: 0.5703 - categorical_accuracy: 0.7934 - val_loss: 1.1299 - val_categorical_accuracy: 0.6800 - lr: 1.0000e-04
# Epoch 13/15
# 67/67 [==============================] - ETA: 0s - loss: 0.4832 - categorical_accuracy: 0.8069
# Epoch 13: val_loss improved from 0.65055 to 0.58591, saving model to model_conv3D_9_2023-08-2513_52_56.201412/model-00013-0.48323-0.80694-0.58591-0.76000.h5
# 67/67 [==============================] - 228s 3s/step - loss: 0.4832 - categorical_accuracy: 0.8069 - val_loss: 0.5859 - val_categorical_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 14/15
# 67/67 [==============================] - ETA: 0s - loss: 0.4323 - categorical_accuracy: 0.8492
# Epoch 14: val_loss did not improve from 0.58591
# 67/67 [==============================] - 218s 3s/step - loss: 0.4323 - categorical_accuracy: 0.8492 - val_loss: 0.9893 - val_categorical_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 15/15
# 67/67 [==============================] - ETA: 0s - loss: 0.3854 - categorical_accuracy: 0.8627
# Epoch 15: val_loss did not improve from 0.58591
# 67/67 [==============================] - 235s 4s/step - loss: 0.3854 - categorical_accuracy: 0.8627 - val_loss: 0.6324 - val_categorical_accuracy: 0.7700 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# TRANSFER LEARNING - MobileNet Conv2d + GRU

# %%
from keras.applications import mobilenet

def mobilenet_RNN(fine_tune=False, gru=False, lstm_gru_cells=128, dense_nodes=128, dropout=0.25, num_images=20, height=120, width=120):

    mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)
    print("Number of layers in the pretrained mobilenet model: ", len(mobilenet_transfer.layers))

    if (fine_tune):
        # Fine-tune from this layer onwards
        fine_tune_at = 50
        # Freeze all the layers before the `fine_tune_at` layer
        for layer in mobilenet_transfer.layers[:fine_tune_at]:
            layer.trainable = False

    model = Sequential()
    model.add(TimeDistributed(mobilenet_transfer,input_shape=(num_images, height, width, 3)))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Flatten()))
    if (gru):
        model.add(GRU(lstm_gru_cells))
    else:
        model.add(LSTM(lstm_gru_cells))
    model.add(Dropout(dropout))
    model.add(Dense(dense_nodes, activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(num_classes, activation='softmax'))

    opt = optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    return model

# %% [markdown]
# Mobilenet (re train all weights) + GRU (128 cells) + 128 dense nodes

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(num_images=num_frames, gru=True)
print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num frames per video = 20
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 20, 3, 3, 1024)   3228864
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 20, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 20, 1, 1, 1024)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 20, 1024)         0
#  tributed)
#
#  gru (GRU)                   (None, 128)               443136
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 128)               16512
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________
# None

# %% [markdown]
# The steps_per_epoch and validation_steps are used by fit_generator to decide the number of next() calls it need to make. Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 67/67 [==============================] - ETA: 0s - loss: 1.0329 - categorical_accuracy: 0.6018
# Epoch 1: val_loss improved from inf to 0.74757, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-
20
# 67/67 [==============================] - ETA: 0s - loss: 0.1150 - categorical_accuracy: 0.9653
# Epoch 12: val_loss did not improve from 0.13603
# 67/67 [==============================] - 169s 3s/step - loss: 0.1150 - categorical_accuracy: 0.9653 - val_loss: 0.2019 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0923 - categorical_accuracy: 0.9698
# Epoch 13: val_loss did not improve from 0.13603
# 67/67 [==============================] - 163s 2s/step - loss: 0.0923 - categorical_accuracy: 0.9698 - val_loss: 0.1432 - val_categorical_accuracy: 0.9400 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0585 - categorical_accuracy: 0.9804
# Epoch 14: val_loss improved from 0.13603 to 0.09308, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00014-0.05846-0.98039-0.09308-0.96000.h5
# 67/67 [==============================] - 147s 2s/step - loss: 0.0585 - categorical_accuracy: 0.9804 - val_loss: 0.0931 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0394 - categorical_accuracy: 0.9894
# Epoch 15: val_loss did not improve from 0.09308
# 67/67 [==============================] - 144s 2s/step - loss: 0.0394 - categorical_accuracy: 0.9894 - val_loss: 0.1339 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0502 - categorical_accuracy: 0.9864
# Epoch 16: val_loss did not improve from 0.09308
# 67/67 [==============================] - 142s 2s/step - loss: 0.0502 - categorical_accuracy: 0.9864 - val_loss: 0.1130 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0340 - categorical_accuracy: 0.9879
# Epoch 17: val_loss improved from 0.09308 to 0.08886, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00017-0.03402-0.98793-0.08886-0.97000.h5
# 67/67 [==============================] - 144s 2s/step - loss: 0.0340 - categorical_accuracy: 0.9879 - val_loss: 0.0889 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0321 - categorical_accuracy: 0.9925
# Epoch 18: val_loss improved from 0.08886 to 0.04819, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00018-0.03208-0.99246-0.04819-0.97000.h5
# 67/67 [==============================] - 171s 3s/step - loss: 0.0321 - categorical_accuracy: 0.9925 - val_loss: 0.0482 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0246 - categorical_accuracy: 0.9955
# Epoch 19: val_loss did not improve from 0.04819
# 67/67 [==============================] - 163s 2s/step - loss: 0.0246 - categorical_accuracy: 0.9955 - val_loss: 0.1286 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0216 - categorical_accuracy: 0.9940
# Epoch 20: val_loss did not improve from 0.04819
# 67/67 [==============================] - 141s 2s/step - loss: 0.0216 - categorical_accuracy: 0.9940 - val_loss: 0.1046 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])

# %% [markdown]
# Mobilenet (re train all weights) + GRU (128 cells) + 128 dense nodes + Random data transformations on training data set

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(gru=True, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num frames per video = 30
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_4 (TimeDis  (None, 30, 3, 3, 1024)   3228864
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 30, 3, 3, 1024)   4096
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 30, 1, 1, 1024)   0
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 30, 1024)         0
#  tributed)
#
#  gru_1 (GRU)                 (None, 128)               443136
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_14 (Dense)            (None, 128)               16512
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# 67/67 [==============================] - ETA: 0s - loss: 1.1884 - categorical_accuracy: 0.5143
# Epoch 1: val_loss improved from inf to 0.90542, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00001-1.18843-0.51433-0.90542-0.58000.h5
# 67/67 [==============================] - 263s 4s/step - loss: 1.1884 - categorical_accuracy: 0.5143 - val_loss: 0.9054 - val_categorical_accuracy: 0.5800 - lr: 0.0010
# Epoch 2/20
# 67/67 [==============================] - ETA: 0s - loss: 0.5200 - categorical_accuracy: 0.8069
# Epoch 2: val_loss improved from 0.90542 to 0.46792, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00002-0.51996-0.80694-0.46792-0.75000.h5
# 67/67 [==============================] - 250s 4s/step - loss: 0.5200 - categorical_accuracy: 0.8069 - val_loss: 0.4679 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 3/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3338 - categorical_accuracy: 0.8763
# Epoch 3: val_loss improved from 0.46792 to 0.28220, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00003-0.33385-0.87632-0.28220-0.90000.h5
# 67/67 [==============================] - 246s 4s/step - loss: 0.3338 - categorical_accuracy: 0.8763 - val_loss: 0.2822 - val_categorical_accuracy: 0.9000 - lr: 0.0010
# Epoch 4/20
# 67/67 [==============================] - ETA: 0s - loss: 0.3287 - categorical_accuracy: 0.8808
# Epoch 4: val_loss did not improve from 0.28220
# 67/67 [==============================] - 239s 4s/step - loss: 0.3287 - categorical_accuracy: 0.8808 - val_loss: 0.5035 - val_categorical_accuracy: 0.8500 - lr: 0.0010
# Epoch 5/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2446 - categorical_accuracy: 0.9110
# Epoch 5: val_loss did not improve from 0.28220
# 67/67 [==============================] - 243s 4s/step - loss: 0.2446 - categorical_accuracy: 0.9110 - val_loss: 0.7855 - val_categorical_accuracy: 0.7900 - lr: 0.0010
# Epoch 6/20
# 67/67 [==============================] - ETA: 0s - loss: 0.2231 - categorical_accuracy: 0.9291
# Epoch 6: val_loss improved from 0.28220 to 0.14631, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00006-0.22307-0.92911-0.14631-0.96000.h5
# 67/67 [==============================] - 247s 4s/step - loss: 0.2231 - categorical_accuracy: 0.9291 - val_loss: 0.1463 - val_categorical_accuracy: 0.9600 - lr: 0.0010
# Epoch 7/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1291 - categorical_accuracy: 0.9593
# Epoch 7: val_loss improved from 0.14631 to 0.13871, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00007-0.12911-0.95928-0.13871-0.95000.h5
# 67/67 [==============================] - 244s 4s/step - loss: 0.1291 - categorical_accuracy: 0.9593 - val_loss: 0.1387 - val_categorical_accuracy: 0.9500 - lr: 0.0010
# Epoch 8/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1521 - categorical_accuracy: 0.9563
# Epoch 8: val_loss did not improve from 0.13871
# 67/67 [==============================] - 268s 4s/step - loss: 0.1521 - categorical_accuracy: 0.9563 - val_loss: 0.2597 - val_categorical_accuracy: 0.9100 - lr: 0.0010
# Epoch 9/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1307 - categorical_accuracy: 0.9668
# Epoch 9: val_loss did not improve from 0.13871
# 67/67 [==============================] - 251s 4s/step - loss: 0.1307 - categorical_accuracy: 0.9668 - val_loss: 0.4859 - val_categorical_accuracy: 0.8300 - lr: 0.0010
# Epoch 10/20
# 67/67 [==============================] - ETA: 0s - loss: 0.1508 - categorical_accuracy: 0.9427
# Epoch 10: val_loss did not improve from 0.13871
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 246s 4s/step - loss: 0.1508 - categorical_accuracy: 0.9427 - val_loss: 0.3788 - val_categorical_accuracy: 0.8800 - lr: 0.0010
# Epoch 11/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0933 - categorical_accuracy: 0.9729
# Epoch 11: val_loss improved from 0.13871 to 0.12582, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00011-0.09332-0.97285-0.12582-0.96000.h5
# 67/67 [==============================] - 243s 4s/step - loss: 0.0933 - categorical_accuracy: 0.9729 - val_loss: 0.1258 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 12/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0631 - categorical_accuracy: 0.9819
# Epoch 12: val_loss improved from 0.12582 to 0.09415, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00012-0.06314-0.98190-0.09415-0.97000.h5
# 67/67 [==============================] - 241s 4s/step - loss: 0.0631 - categorical_accuracy: 0.9819 - val_loss: 0.0942 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 13/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0519 - categorical_accuracy: 0.9819
# Epoch 13: val_loss improved from 0.09415 to 0.08172, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00013-0.05191-0.98190-0.08172-0.97000.h5
# 67/67 [==============================] - 250s 4s/step - loss: 0.0519 - categorical_accuracy: 0.9819 - val_loss: 0.0817 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 14/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0451 - categorical_accuracy: 0.9925
# Epoch 14: val_loss did not improve from 0.08172
# 67/67 [==============================] - 246s 4s/step - loss: 0.0451 - categorical_accuracy: 0.9925 - val_loss: 0.1780 - val_categorical_accuracy: 0.9100 - lr: 1.0000e-04
# Epoch 15/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0300 - categorical_accuracy: 0.9925
# Epoch 15: val_loss did not improve from 0.08172
# 67/67 [==============================] - 243s 4s/step - loss: 0.0300 - categorical_accuracy: 0.9925 - val_loss: 0.1045 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 16/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0254 - categorical_accuracy: 0.9955
# Epoch 16: val_loss did not improve from 0.08172
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 [==============================] - 245s 4s/step - loss: 0.0254 - categorical_accuracy: 0.9955 - val_loss: 0.1090 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 17/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0216 - categorical_accuracy: 0.9940
# Epoch 17: val_loss did not improve from 0.08172
# 67/67 [==============================] - 236s 4s/step - loss: 0.0216 - categorical_accuracy: 0.9940 - val_loss: 0.1157 - val_categorical_accuracy: 0.9500 - lr: 1.0000e-04
# Epoch 18/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0224 - categorical_accuracy: 0.9970
# Epoch 18: val_loss did not improve from 0.08172
# 67/67 [==============================] - 244s 4s/step - loss: 0.0224 - categorical_accuracy: 0.9970 - val_loss: 0.1130 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04
# Epoch 19/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0103 - categorical_accuracy: 0.9985
# Epoch 19: val_loss did not improve from 0.08172
# 67/67 [==============================] - 238s 4s/step - loss: 0.0103 - categorical_accuracy: 0.9985 - val_loss: 0.1028 - val_categorical_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 20/20
# 67/67 [==============================] - ETA: 0s - loss: 0.0141 - categorical_accuracy: 0.9940
# Epoch 20: val_loss improved from 0.08172 to 0.06705, saving model to model_retrain_mobilenet_gru_2023-08-2513_52_56.201412/model-00020-0.01410-0.99397-0.06705-0.97000.h5
# 67/67 [==============================] - 253s 4s/step - loss: 0.0141 - categorical_accuracy: 0.9940 - val_loss: 0.0671 - val_categorical_accuracy: 0.9700 - lr: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy', 'lr'])
